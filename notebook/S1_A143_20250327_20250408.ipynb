# %%
# %matplotlib inline
import os
import numpy as np
import platform
from matplotlib import pyplot as plt
from mintpy.utils import ptime, readfile, writefile, isce_utils, utils as ut, plot as pp
from mintpy.cli import geocode, view
from mintpy.view import prep_slice, plot_slice
plt.rcParams.update({'font.size': 12})

ds_name = ['S1_A143_20250327_20250408_RG', 'S1_A143_20250327_20250408_AZ'][0]
work_dir = '/home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1'
redo = True

os.chdir(work_dir)
print('Go to directory:', work_dir)

# grid
S, N, W, E = 16.5, 24, 94, 98   # same as Fig. 1;  36.0, 39.0, 35.8, 38.8
step = 0.00277778   # deg (~300 m)  # set to None to calculate product resolution for reference

# input files
off_file = os.path.join(work_dir, 'filt_dense_offsets.bil')
cov_file = os.path.join(work_dir, 'dense_offsets_cov.bil')
snr_file = os.path.join(work_dir, 'dense_offsets_snr.bil')
lat_file = os.path.join(work_dir, 'lat.rdr.mli')
lon_file = os.path.join(work_dir, 'lon.rdr.mli')
los_file = os.path.join(work_dir, 'los.rdr.mli')
hgt_file = os.path.join(work_dir, 'z.rdr.mli')
msk_file = os.path.join(work_dir, 'waterMask.rdr')
xml_file = os.path.join(work_dir, '../../referencedir/IW1.xml')
atr = readfile.read_attribute(off_file)

# output files
rdr_file = os.path.join(work_dir, 'offRg.h5' if ds_name.endswith('RG') else 'offAz.h5')
# Out:
# Go to directory: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1

# %%
# utils functions
def read_offset():
    # calculate pixel_size (to convert offset unit from pixel to meters)
    meta = isce_utils.extract_isce_metadata(xml_file, update_mode=False)[0]

    obs_dir = 'range' if ds_name.endswith('RG') else 'azimuth'
    if obs_dir == 'range':
        pixel_size = float(meta['RANGE_PIXEL_SIZE'])
        print('Slant range pixel size: {:.2f} m'.format(pixel_size))
    else:
        Re, h_sat = float(meta['EARTH_RADIUS']), float(meta['HEIGHT'])
        pixel_size = float(meta['AZIMUTH_PIXEL_SIZE']) * Re / (Re + h_sat)
        print('Ground azimuth pixel size: {:.2f} m'.format(pixel_size))

    # read data / attribute
    off = readfile.read(off_file, datasetName=f'{obs_dir}Offset')[0] * pixel_size
    off_std = np.sqrt(readfile.read(cov_file, datasetName=f'{obs_dir}OffsetStd')[0]) * pixel_size
    off_snr = readfile.read(snr_file)[0]

    return off, off_std, off_snr


def mask_offset(off, off_std, off_snr, config):
    # 1. ignore no-data-value
    no_data_value = readfile.get_no_data_value(off_file)
    off[off == no_data_value] = np.nan
    print(f'# of pixels after removing no-data-value ({no_data_value}): {count(off)} out of {off.size} ({count(off)/off.size*100:.1f}%)')

    # 2. ignore water body
    water_mask = readfile.read(msk_file)[0]
    off[water_mask == 0] = np.nan
    off_std[water_mask == 0] = np.nan
    off_snr[water_mask == 0] = np.nan
    print(f'# of pixels after removing water body: {count(off)} out of {off.size} ({count(off)/off.size*100:.1f}%)')
    off_raw = np.array(off, dtype=np.float32)

    # 3. remove pixels with abnormal offset
    off_std[np.isnan(off)] = np.nan
    off[np.abs(off) > config['max_off']] = np.nan
    print(f'# of pixels after removing offset > {config["max_off"]}: {count(off)} out of {off.size} ({count(off)/off.size*100:.1f}%)')

    # 4. remove pixels with low offset SNR
    off[np.isnan(off_snr)] = np.nan
    flag = off_snr < config['min_snr']    # remove pixels with low SNR value
    flag[np.abs(off / off_std) > 3] = 0   # keep   pixels with high off / off_std
    flag[off_snr < 1] = 1                 # remove pixels with very low SNR value
    off[flag] = np.nan
    print(f'# of pixels after removing SNR < {config["min_snr"]}: {count(off)} out of {off.size} ({count(off)/off.size*100:.1f}%)')

    # 5. remove pixels with high offset STD
    off_std[off_std > config['max_off']/2] = np.nan
    off[np.isnan(off_std)] = np.nan
    off[off_std > config['max_std']] = np.nan
    print(f'# of pixels after removing STD > {config["max_std"]}: {count(off)} out of {off.size} ({count(off)/off.size*100:.1f}%)')

    return off, off_std, off_snr, off_raw


def count(data):
    """Count the number of valid pixels"""
    return np.sum(~np.isnan(data))

print('warm up utils functions.')
# Out:
# warm up utils functions.

# %%
config = {
    'S1_A143_20250327_20250408_RG': {'max_off': 5, 'min_snr': 5, 'max_std': 0.5},
    'S1_A143_20250327_20250408_AZ': {'max_off': 5, 'min_snr': 3, 'max_std': 1.5},
}[ds_name]

# read and mask
off, off_std, off_snr = read_offset()
off, off_std, off_snr, off_raw = mask_offset(off, off_std, off_snr, config)

# write to one HDF5 files
atr['ORBIT_DIRECTION'] = 'ASCENDING' if ds_name.startswith('S1_A') else 'DESCENDING'
if redo or not os.path.isfile(rdr_file):
    ds_dict      = {'displacement' : np.array(off, dtype=np.float32), 'displacementStd' : np.array(off_std, dtype=np.float32)}
    ds_unit_dict = {'displacement' : 'm', 'displacementStd' : 'm'}
    writefile.write(ds_dict, out_file=rdr_file, metadata=atr, ds_unit_dict=ds_unit_dict, compression='lzf', print_msg=False)

# plot
# %matplotlib widget
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=[10, 8], sharex=True, sharey=True)
for ax, data, [vmin, vmax], cmap, title in zip(axs.flatten(), [off_raw, off, off_std, off_snr], [[-4, 4], [-3, 3], [0, config['max_std']], [2, config['min_snr']+1]], ['RdBu', 'RdBu', 'RdBu_r', 'RdBu'], ['offset raw', 'offset', 'offset STD', 'offset SNR']):
    im = ax.imshow(data, cmap=cmap, vmin=vmin, vmax=vmax, interpolation='nearest'); fig.colorbar(im, ax=ax, aspect=50); pp.auto_flip_direction(atr, ax, print_msg=False); ax.set_title(title)
fig.tight_layout()
plt.show()
# Out:
# extract metadata from ISCE/topsStack xml file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/../../referencedir/IW1.xml
# Slant range pixel size: 2.33 m
# # of pixels after removing no-data-value (-10000.0): 2032020 out of 2032020 (100.0%)
# # of pixels after removing water body: 1954025 out of 2032020 (96.2%)
# # of pixels after removing offset > 5: 1927034 out of 2032020 (94.8%)
# # of pixels after removing SNR < 5: 1804652 out of 2032020 (88.8%)
# # of pixels after removing STD > 0.5: 1798216 out of 2032020 (88.5%)
# create HDF5 file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.h5 with w mode
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if step is None:
    iw_xml_file = os.path.join(proj_dir, ds_name, 'referencedir/IW1.xml')
    meta = isce_utils.extract_isce_metadata(iw_xml_file)[0]
    meta['WIDTH'] = int(atr['WIDTH']) * 64
    ystep_m = ut.azimuth_ground_resolution(meta) * 32;  ystep_d = ystep_m / 108e3
    xstep_m = ut.range_ground_resolution(meta) * 64;    xstep_d = xstep_m / (108e3 * np.cos(np.deg2rad(37)))
    print(f'y/x step: {ystep_m:.1f} / {xstep_m:.1f} m; {ystep_d:.4f}, {xstep_d:.4f} deg')

# %%
opt = f'--lat-file {lat_file} --lon-file {lon_file} --fill nan --bbox {S} {N} {W} {E} --lalo -{step} {step}'
fbase = os.path.splitext(rdr_file)[0]
io_files = [
    [rdr_file, '--dset displacement',    f'{fbase}.geo'],      # offset
    [rdr_file, '--dset displacementStd', f'{fbase}Std.geo'],   # offset STD
    [los_file, '', os.path.join(work_dir, 'los.geo')]          # offset geometry
]
for ifile, dset, ofile in io_files:
    if redo or not os.path.isfile(ofile):
        cmd = f'{ifile} {dset} -o {ofile} {opt}'
        print(f'geocode.py {cmd}')
        geocode.main(cmd.split())

# plot
view.main(f'{fbase}.geo -c RdBu --noverbose'.split())
# Out:
# geocode.py /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.h5 --dset displacement -o /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo --lat-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli --lon-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lon.rdr.mli --fill nan --bbox 16.5 24 94 98 --lalo -0.00277778 0.00277778
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli
# output pixel size in (lat, lon) in degree: (-0.00277778, 0.00277778)
# output area extent in (S, N, W, E) in degree: (16.499994, 24.0, 94.0, 98.0000032)
# output file row / column number: (2700, 1440)
# [1/1] preparing geometry for dest_box: (0, 0, 1440, 2700) --> full src_box: (0, 0, 1060, 1917)
# --------------------------------------------------
# resampling file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.h5
# --------------------------------------------------1/1
# reading displacement in block (0, 0, 1060, 1917) from offRg.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo.xml
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo.vrt
# time used: 00 mins 1.0 secs.
#
# geocode.py /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.h5 --dset displacementStd -o /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRgStd.geo --lat-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli --lon-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lon.rdr.mli --fill nan --bbox 16.5 24 94 98 --lalo -0.00277778 0.00277778
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli
# output pixel size in (lat, lon) in degree: (-0.00277778, 0.00277778)
# output area extent in (S, N, W, E) in degree: (16.499994, 24.0, 94.0, 98.0000032)
# output file row / column number: (2700, 1440)
# [1/1] preparing geometry for dest_box: (0, 0, 1440, 2700) --> full src_box: (0, 0, 1060, 1917)
# --------------------------------------------------
# resampling file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.h5
# --------------------------------------------------1/1
# reading displacementStd in block (0, 0, 1060, 1917) from offRg.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRgStd.geo
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRgStd.geo.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRgStd.geo.xml
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRgStd.geo.vrt
# time used: 00 mins 1.0 secs.
#
# geocode.py /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.rdr.mli  -o /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.geo --lat-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli --lon-file /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lon.rdr.mli --fill nan --bbox 16.5 24 94 98 --lalo -0.00277778 0.00277778
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli
# output pixel size in (lat, lon) in degree: (-0.00277778, 0.00277778)
# output area extent in (S, N, W, E) in degree: (16.499994, 24.0, 94.0, 98.0000032)
# output file row / column number: (2700, 1440)
# [1/1] preparing geometry for dest_box: (0, 0, 1440, 2700) --> full src_box: (0, 0, 1060, 1917)
# --------------------------------------------------
# resampling file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.rdr.mli
# --------------------------------------------------1/1
# reading incidenceAngle in block (0, 0, 1060, 1917) from los.rdr.mli ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# --------------------------------------------------1/1
# reading azimuthAngle   in block (0, 0, 1060, 1917) from los.rdr.mli ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.geo
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.geo.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.geo.xml
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.geo.vrt
# time used: 00 mins 1.8 secs.
#
# view.py /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo -c RdBu --noverbose
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from mintpy.cli import load_data, smallbaselineApp
# write geometry HDF5 file
config = f"""# vim: set filetype=cfg:
########## 1. Load Data (--load to exit after this step)
## load_data.py -H to check more details and example inputs.
mintpy.load.processor        = isce
##---------for ISCE only:
mintpy.load.metaFile         = {os.path.join(work_dir, '../../referencedir/IW1.xml')}
mintpy.load.baselineDir      = None
##---------geometry datasets:
mintpy.load.demFile          = {hgt_file}
mintpy.load.lookupYFile      = {lat_file}
mintpy.load.lookupXFile      = {lon_file}
mintpy.load.incAngleFile     = {los_file}
mintpy.load.azAngleFile      = {los_file}
mintpy.load.waterMaskFile    = {msk_file}
"""
sname, oname = ds_name.split('_')[:2]
config_file = os.path.join(work_dir, f'{sname}_{oname}.txt')
print('write MintPy configuration to file: {}'.format(config_file))
with open(config_file, "w") as fid:
    fid.write(config)
smallbaselineApp.main(f'{config_file} -g'.split())
# write geometryRadar.h5
load_data.main(f'-t smallbaselineApp.cfg --geom'.split())
# write geometryGeo.h5
geocode.main(f'./inputs/geometryRadar.h5 -o ./inputs/geometryGeo.h5 {opt}'.split())
# Out:
# write MintPy configuration to file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/S1_A143.txt
# --------------------------------------------------
# Project name: S1_A143
# Go to work directory: /penguin/eedy/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1
# read custom template file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/S1_A143.txt
# update default template based on input custom template
# No new option value found, skip updating /penguin/eedy/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/smallbaselineApp.cfg
# copy S1_A143.txt          to inputs   directory for backup.
# copy S1_A143.txt          to pic      directory for backup.
# read default template file: /penguin/eedy/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/smallbaselineApp.cfg
# Go back to directory: /penguin/eedy/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.0 secs
#
# processor : isce
# SAR platform/sensor : unknown from project name "None"
# --------------------------------------------------
# prepare metadata files for isce products
# prep_isce.py -m /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/../../referencedir/IW1.xml -g /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1 --geom-files z.rdr.mli lat.rdr.mli lon.rdr.mli los.rdr.mli los.rdr.mli waterMask.rdr
# ['/home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/../../referencedir/data.rsc'] exists and is newer than ['/home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/../../referencedir/IW1.xml'] --> skip.
# preparing RSC file for geometry files
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/z.rdr.mli.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lon.rdr.mli.rsc
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.rdr.mli.rsc
# preparing RSC file for: ./merged/interferograms/*/filt_*.unw
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/z.rdr.mli
# latitude        : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli
# longitude       : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lon.rdr.mli
# incidenceAngle  : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.rdr.mli
# azimuthAngle    : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/los.rdr.mli
# waterMask       : /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/waterMask.rdr
# All datasets exists in file geometryRadar.h5 with same size as required, no need to re-load.
# time used: 00 mins 0.0 secs.
#
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/lat.rdr.mli
# output pixel size in (lat, lon) in degree: (-0.00277778, 0.00277778)
# output area extent in (S, N, W, E) in degree: (16.499994, 24.0, 94.0, 98.0000032)
# output file row / column number: (2700, 1440)
# /home/eedy/tools/MintPy/src/mintpy/load_data.py:711: UserWarning: prep_isce.py failed. Assuming its result exists and continue...
#   warnings.warn('prep_isce.py failed. Assuming its result exists and continue...')
# [1/1] preparing geometry for dest_box: (0, 0, 1440, 2700) --> full src_box: (0, 0, 1060, 1917)
# --------------------------------------------------
# resampling file: ./inputs/geometryRadar.h5
# --------------------------------------------------
# grab dataset structure from ref_file: ./inputs/geometryRadar.h5
# create HDF5 file: ./inputs/geometryGeo.h5 with w mode
# create dataset  : azimuthAngle       of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : height             of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : incidenceAngle     of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : latitude           of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : longitude          of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : slantRangeDistance of float32                   in size of (2700, 1440)         with compression = lzf
# create dataset  : waterMask          of bool                      in size of (2700, 1440)         with compression = lzf
# close  HDF5 file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading azimuthAngle       in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading height             in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading incidenceAngle     in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading latitude           in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading longitude          in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading slantRangeDistance in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# --------------------------------------------------1/1
# reading waterMask          in block (0, 0, 1060, 1917) from geometryRadar.h5 ...
# input source data is bool type, restrict fill_value to False.
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 5 segments ...
# write data in block [0, 2700, 0, 1440] to file: ./inputs/geometryGeo.h5
# time used: 00 mins 6.4 secs.

# %%
# add some metadata
meta = readfile.read_roipac_rsc(f'../../referencedir/data.rsc')
atr0 = readfile.read_attribute('./offRg.geo')
for key in atr0.keys():
    if key in meta.keys():
        meta.pop(key)
meta['DATE12'] = ptime.yymmdd_date12(ptime.get_date12_from_path(ds_name))
meta['FILE_TYPE'] = 'displacement'
ut.add_attribute('./offRg.geo', meta, print_msg=True)
# Out:
# add/update ALOOKS = 1
# add/update ANTENNA_SIDE = -1
# add/update AZIMUTH_PIXEL_SIZE = 15.617466268790077
# add/update CENTER_INCIDENCE_ANGLE = 43.764137
# add/update CENTER_LINE_UTC = 42392.0
# add/update EARTH_RADIUS = 6341873.051760971
# add/update HEADING = -12.198979501835213
# add/update HEIGHT = 697951.188777534
# add/update NCORRLOOKS = 0.5988783168332155
# add/update PLATFORM = sen
# add/update POLARIZATION = VV
# add/update PRF = 1717.128973878037
# add/update RANGE_PIXEL_SIZE = 2.329562114715323
# add/update RLOOKS = 1
# add/update STARTING_RANGE = 798984.1304728859
# add/update WAVELENGTH = 0.05546576
# add/update altitude = 697951.188777534
# add/update azimuthPixelSize = 15.617466268790077
# add/update azimuthResolution = 22.5
# add/update beam_mode = IW
# add/update beam_swath = 123
# add/update earthRadius = 6341873.051760971
# add/update firstFrameNumber = 51
# add/update first_frame = 51
# add/update lastFrameNumber = 76
# add/update last_frame = 76
# add/update orbitNumber = 58490
# add/update passDirection = ASCENDING
# add/update polarization = VV
# add/update prf = 1717.128973878037
# add/update radarWavelength = 0.05546576
# add/update rangePixelSize = 2.329562114715323
# add/update rangeResolution = 2.7
# add/update relative_orbit = 143
# add/update satelliteSpeed = 7597.683541331411
# add/update startUTC = 2025-03-27 11:46:32.207303
# add/update startingRange = 798984.1304728859
# add/update stopUTC = 2025-03-27 11:48:37.199821
# add/update swathNumber = 123
# add/update trackNumber = 143
# add/update DATE12 = 250327-250408
# add/update FILE_TYPE = displacement
# write file: ./offRg.geo.rsc
# './offRg.geo'

# %%
# !remove_ramp.py {fbase}.geo -m mask_deramp.h5 -o {fbase}.geo
# Out:
# remove linear ramp from file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo
# read mask file: mask_deramp.h5
# writing >>> /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo.rsc
# add/update the following metadata to file:
# add/update mintpy.deramp = linear
# add/update mintpy.deramp.maskFile = mask_deramp.h5
# write file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo.rsc
# time used: 00 mins 0.3 secs.

# %%
dis_file = f'{fbase}.geo'
dem_file = os.path.join(f'/home/eedy/penguin/25EQ_myanmar/DEM/elevation_mli.dem')
flt_file = os.path.join(f'/home/eedy/penguin/25EQ_myanmar/simple_rupture_trace.lonlat')
out_file = os.path.join(work_dir, f'{ds_name}.png')
cmd = f'{dis_file} --dem {dem_file} --dem-nocontour --shade-exag 0.05 --faultline {flt_file} --faultline-lw 1 '
cmd += f'-c RdBu -v -1 1 --lalo-label --lalo-step 3 --cbar-nbins 5 --scalebar 0.2 0.20 0.10 --title {ds_name} '
cmd += f'-o {out_file} '
view.main(cmd.split())
# Out:
# run view.py in MintPy version 1.6.1.post18, date 2025-01-14
# input file is isce displacement file: /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/offRg.geo in float32 format
# file size in y/x: (2700, 1440)
# num of datasets in file offRg.geo: 1
# datasets to exclude (0):
# []
# datasets to display (1):
# ['band1']
# data   coverage in y/x: (0, 0, 1440, 2700)
# subset coverage in y/x: (0, 0, 1440, 2700)
# data   coverage in lat/lon: (94.0, 24.0, 98.0000032, 16.499994)
# subset coverage in lat/lon: (94.0, 24.0, 98.0000032, 16.499994)
# ------------------------------------------------------------------------
# area exceed 2000 pixels, turn off default DEM contour display
# colormap: RdBu
# initiate cartopy map projection: PlateCarree
# figure title: S1_A143_20250327_20250408_RG
# figure size : [5.3, 8.0]
# reading data ...
# masking pixels with NO_DATA_VALUE of -10000.0
# data    range: [-5.1698895, 5.2206125] m
# display range: [-1.0, 1.0] m
# reading DEM: elevation_mli.dem ...
# display data in transparency: 0.8
# plot in geo-coordinate
# plotting DEM background ...
# show shaded relief DEM (min/max=-4000/4465 m; exag=0.05; az/alt=315.0/45.0 deg)
# plotting data as image via matplotlib.pyplot.imshow ...
# plot fault lines from GMT lonlat file: /home/eedy/penguin/25EQ_myanmar/simple_rupture_trace.lonlat
# plot scale bar: [0.2, 0.2, 0.1]
# plot lat/lon label in step of 3.0 and location of [1, 0, 0, 1]
# save figure to /home/eedy/penguin/25EQ_myanmar/s1_a143/20250327_20250408/merged/dense_v1/S1_A143_20250327_20250408_RG.png with dpi=300
# showing ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
